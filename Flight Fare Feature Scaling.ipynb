# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_excel("Flight_Outliers_Removed.xlsx")

# %%
df_train
# Out:
#        Total_Stops  Price  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 0                0   3897           24              3        22       20
# 1                2   7662            1              5         5       50
# 2                2  13882            9              6         9       25
# 3                1   6218           12              5        18        5
# 4                1  13302            1              3        16       50
# ...            ...    ...          ...            ...       ...      ...
# 10581            0   4107            9              4        19       55
# 10582            0   4145           27              4        20       45
# 10583            0   7229           27              4         8       20
# 10584            0  12648            1              3        11       30
# 10585            2  11753            9              5        10       55
#
#        Arrival_hour  Arrival_minute  Duration_hours  Duration_minutes  ...  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
for feature in df_train.columns:
    plt.figure(figsize = (15 , 5))
    sns.histplot(data = df_train[feature] , kde=True , element='poly')
    plt.xlabel(feature)
    plt.show
# Out:
# C:\Users\AAKASH\anaconda3.1\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <ipython-input-7-d9f6eda4b362>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize = (15 , 5))

# %% [markdown]
# From the above histplots the data seems to be normally distributed. So there is actually no need to normalize the data.
